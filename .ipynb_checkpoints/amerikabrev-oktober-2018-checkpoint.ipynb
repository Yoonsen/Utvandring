# %%
from module_update import update

# %%
update('graph_networkx_louvain')
# Out:
# Updated file graph_networkx_louvain.py

# %%
import graph_networkx_louvain as gnl

# %%
import nbtext as nb

# %%
import requests
import pandas as pd

# %%
from nbtext import collocation, collocation_data

# %%
abrev = nb.get_urn({'title':'%%amerika til%', 'limit':100}) 
abrev
# Out:
# [[2010051906100, '', 'Fra Amerika til Norge', 1992],
#  [2007091801006, '', 'Fra Amerika til Norge', 1992],
#  [2007112704027, '', 'Fra Amerika til Norge', 1993]]

# %%
abrev2 = nb.get_urn({'author':"sunde%rasm%"})
abrev2[1:]
# Out:
# [[2010061503016, 'Sunde, Rasmus', 'utvandrarsoge frå Sogndal', 1994],
#  [2015082548012, 'Sunde, Rasmus', 'Long Prairie', 1994]]

# %%
abrev3 = nb.get_urn({'title':'%%amerika%brev%', 'limit':100}) 
abrev3[:5]
# Out:
# [[2016052608061, 'Engen, Arnfinn', 'Utvandringshistorie og amerikabrev', 1975],
#  [2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2014072406038, '', 'Amerikabrev', 1989],
#  [2013010308006, '', 'Amerikabrev', 2000],
#  [2013041608123, 'Rodegard, Olaf', 'Amerikabrev', 1988]]

# %%
abrev = abrev + abrev2[1:] + abrev3

# %%
dbrev = nb.get_urn({'ddk':'304.8%', 'limit':100})
dbrev
# Out:
# [[2016072248034, 'Sunde, Rasmus', 'stad skal ein vera', 1989],
#  [2007071100083, 'Semmingsen, Ingrid', 'Drøm og dåd', 1975],
#  [2015030208021,
#   'Rynning, Ole',
#   "Ole Rynning's true account of America",
#   1926],
#  [2008101004055, '', 'Utvandring til Amerika', 2000],
#  [2013082708209, 'Strøm, Elin', 'Reisen til Amerika', 1984],
#  [2008041804067, 'Semmingsen, Ingrid', 'Veien mot vest', 1950],
#  [2009031804196, 'Espedal, Kjell', 'Dei som drog', 1998],
#  [2014052208110, '', 'Amerikafeber', 1989],
#  [2008091104009,
#   'Carling, Jørgen',
#   'Arbeidsinnvandring og familiegjenforening 1967-1980',
#   1999],
#  [2009041504136, 'Childers, Anne Salverson', 'Draumen om ei betre verd', 2000],
#  [2008061004002, 'Kuparinen, Eero', 'African alternative', 1991],
#  [2007082401038, 'Thorsen, Laila', 'Russland via Vardø', 1991],
#  [2014071808096, 'Ryningen, Alfred', 'Valle kommune', 2000],
#  [2009062304044,
#   'Andresen, Øystein Molstad',
#   'Uredd ferd mot ukjent land',
#   1999],
#  [2010113008120, '', 'Forskning om innvandring', 1991],
#  [2008020600020, '', 'Frå Sogn til Amerika', 1994],
#  [2014121108068, '', 'Norwegian-American essays 1996', 1996],
#  [2010061503016, 'Sunde, Rasmus', 'utvandrarsoge frå Sogndal', 1994],
#  [2011081808102, 'Lorentzen, Harald', 'Reisen mot vest', 1997],
#  [2015060508068, '', 'Norsk emigrantlitteratur', 2000],
#  [2007070301006, '', 'Cleng Peerson Memorial Institute 1970-1980', 1980],
#  [2013110608132, 'Flå, Vibeke', 'Utvandring og intern flytting', 1995],
#  [2008081200101, 'Tjernsberg, Torbjørn', 'Under sydkorset', 1997],
#  [2014022408011, '', 'Eit blidare tilvere?', 1986],
#  [2016081708001, 'Håtveit, Arnt Edvin', 'Saude og Nes', 2000],
#  [2008030704035, 'Ramsfjell, Berit Sagen', 'De fant et nytt hjem', 1995],
#  [2014111438043,
#   'Knudsen, Knud',
#   'Beretning om en Reise fra Drammen i Norge til New-York i Nord-America',
#   1986],
#  [2016090508041, 'Prestgard, Semon', 'Heidal', 1992],
#  [2013061708050, 'Røine, Bengt-Arne', 'Drømmen om Alaskagullet', 1982],
#  [2016052608061, 'Engen, Arnfinn', 'Utvandringshistorie og amerikabrev', 1975],
#  [2009011304040,
#   'Gjerstad, Joralf',
#   'Snåsninger og andre nordmenn i Vesterled',
#   1998],
#  [2014032408136, '', 'Utvandring frå Voss til Amerika', 1985],
#  [2008012500037, 'Møller, Arvid', 'Drømmenes land', 1994],
#  [2008022600001,
#   'Øverland, Orm',
#   '"Det smærter mig meget at nedskrive disse Linjer til Eder"',
#   1995],
#  [2011022808164, '', 'Norsk emigrantlitteratur', 2000],
#  [2010121406059, 'Sogner, Sølvi', 'Ung i Europa', 1994],
#  [2012071208196, '', 'Utvandrere fra Otterøya til Amerika 1840-1920', 1994],
#  [2008101400073, 'Rorgemoen, Dag', 'mange val', 2000],
#  [2015091106113,
#   'Engen, Arnfinn',
#   'To artiklar om utvandring / Arnfinn Engen',
#   1977],
#  [2008062600001, 'Coron, Edith', 'store utvandringen', 1994],
#  [2008010200003, 'Moe, Jon', 'Kari', 1994],
#  [2009042104066,
#   'Skretting, Harald',
#   "In my father's footsteps - 75 years later",
#   2000],
#  [2008012800046,
#   'Skretting, Harald',
#   'I far sine fotefar - 75 år etter',
#   1994],
#  [2008061904063, 'Nilsen, Tom', 'Canada-feber', 1996],
#  [2016062308064, 'Kvam, Arne', 'Utvandrere fra Grong til Amerika', 1985],
#  [2014091006057, 'Bye, Erik', 'Blow, silver wind', 1978],
#  [2012083108009, 'Hauger, Torill Thorstad', 'store Chicagoreisen', 1988],
#  [2008021100126,
#   'Bakken, Reidar',
#   'Lad ingen sladdrelystne læse mine brever-',
#   1995],
#  [2010030303045,
#   'Brochmann, Grete',
#   'European integration and immigration from third countries',
#   1996],
#  [2014072908035,
#   'Hovdhaugen, Einar',
#   'Utvandringa til Amerika frå Ringebu',
#   1983],
#  [2012070606114, 'Bysveen, Tor', 'Boligskifter i Norge', 1983],
#  [2016010408270, 'Hasund, Knut J.', 'Ulstein og Hareid i Amerika', 1986],
#  [2012091008112,
#   'Gjersvik, Martin',
#   'De som dro fra Karmøy til Amerika =',
#   1984],
#  [2015112708157, 'Standal, Ragnar', 'Mot nye heimland', 1985],
#  [2008112500115, 'Sørdal, Abram Kjell', 'Utvandringen til Amerika', 2000],
#  [2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2009090400012, '', 'Migrasjon i Norden', 1997],
#  [2007082100077, '', 'Migrasjonsforskning i Norge 1980-1990', 1990],
#  [2012102608105, '', 'They came from Norway', 1975],
#  [2012061406142, 'Ottosen, Rune', 'Mitt nye hjemland', 1987]]

# %%
dbrev = nb.get_urn({'yearfrom':1850, 'yearto':1940, 'limit':200})
dbrev[:5]
# Out:
# [[2009100704042, 'Lichtwarck, Willy', 'Habiliteringstjenesten', 1993],
#  [2012122005027,
#   'Breivik, Møyfrid',
#   'Bruk av bøker og bibliotek sammen med psykisk utviklingshemmede barn, unge og voksne',
#   1981],
#  [2007121300043, '', 'Micro80', 1994],
#  [2015062408114, '', 'Litteraturliste', 1978],
#  [2009060300003, 'Broch, Ingvild', 'Zdravstvujte!', 1992]]

# %%
fs = [nb.get_freq(u[0], top=0, cutoff=0) for u in abrev]
from collections import Counter
fsum = Counter()
for f in fs:
    fsum += f

# %%
gs = [nb.get_freq(u[0], top=0, cutoff=0) for u in dbrev]
from collections import Counter
dsum = Counter()
for f in gs:
    dsum += f

# %%
brev = pd.DataFrame.from_dict(fsum, orient='index')
brev.columns = ['brev']
ref = pd.DataFrame.from_dict(dsum, orient='index')
ref.columns = ['ref']
nb.normalize_corpus_dataframe(brev)
nb.normalize_corpus_dataframe(ref)
# Out:
# True

# %%
combo = (brev.join(ref)).fillna(0.8)

# %%
"Iowa" "lowa"
# Out:
# 'Iowalowa'

# %%
pd.DataFrame((combo['brev']**1.06/combo['ref'])).sort_values(by=0, ascending=False)
# Out:
#                         0
# Dollar       1.817162e+03
# Dane         9.224131e+02
# Scandia      9.061253e+02
# Wisconsin    9.032252e+02
# Hilse        7.401815e+02
# lowa         6.226675e+02
# iaa          5.595354e+02
# Kjere        4.737444e+02
# Minnesota    4.557241e+02
# Dakota       3.840274e+02
# Prairie      3.524351e+02
# Registre     3.459949e+02
# tømmermann   3.456234e+02
# utvandringa  3.415207e+02
# Grimstad     3.340063e+02
# Hvide        3.292416e+02
# fea          2.993121e+02
# enu          2.916726e+02
# maaskee      2.802346e+02
# Gasmann      2.764278e+02
# Skare        2.762797e+02
# Daler        2.735934e+02
# Landvik      2.684541e+02
# ikkt         2.585040e+02
# isammen      2.347568e+02
# Indianerne   2.272230e+02
# væl          2.234614e+02
# Fjære        2.220226e+02
# kas          2.143406e+02
# forældre     2.134013e+02
# ...                   ...
# iwumL        3.692188e-07
# iwisJbe      3.692188e-07
# iwug         3.692188e-07
# iwuas        3.692188e-07
# iwuMt        3.692188e-07
# iwttui       3.692188e-07
# iwtta        3.692188e-07
# iwts         3.692188e-07
# iwti         3.692188e-07
# iwt-         3.692188e-07
# iwst         3.692188e-07
# Bækkum       3.692188e-07
# iwqk         3.692188e-07
# iwqjei       3.692188e-07
# iwqjdt       3.692188e-07
# iwqit        3.692188e-07
# iwqLt        3.692188e-07
# iwnt         3.692188e-07
# iwnlJbg      3.692188e-07
# iwna         3.692188e-07
# iwmul        3.692188e-07
# iwml         3.692188e-07
# iwmi         3.692188e-07
# iwjujjex     3.692188e-07
# iwjtje       3.692188e-07
# iwjjlj       3.692188e-07
# iwjjl        3.692188e-07
# iwjji        3.692188e-07
# iwjOxL       3.692188e-07
# 09394        3.692188e-07
#
# [112846 rows x 1 columns]

# %%
df_combo = pd.DataFrame(combo['brev']**1/combo['ref'])

# %%
pd.DataFrame(combo['brev']**1.06/combo['ref']).sort_values(by=0, ascending=False)
# Out:
#                         0
# Dollar       1.817162e+03
# Dane         9.224131e+02
# Scandia      9.061253e+02
# Wisconsin    9.032252e+02
# Hilse        7.401815e+02
# lowa         6.226675e+02
# iaa          5.595354e+02
# Kjere        4.737444e+02
# Minnesota    4.557241e+02
# Dakota       3.840274e+02
# Prairie      3.524351e+02
# Registre     3.459949e+02
# tømmermann   3.456234e+02
# utvandringa  3.415207e+02
# Grimstad     3.340063e+02
# Hvide        3.292416e+02
# fea          2.993121e+02
# enu          2.916726e+02
# maaskee      2.802346e+02
# Gasmann      2.764278e+02
# Skare        2.762797e+02
# Daler        2.735934e+02
# Landvik      2.684541e+02
# ikkt         2.585040e+02
# isammen      2.347568e+02
# Indianerne   2.272230e+02
# væl          2.234614e+02
# Fjære        2.220226e+02
# kas          2.143406e+02
# forældre     2.134013e+02
# ...                   ...
# iwumL        3.692188e-07
# iwisJbe      3.692188e-07
# iwug         3.692188e-07
# iwuas        3.692188e-07
# iwuMt        3.692188e-07
# iwttui       3.692188e-07
# iwtta        3.692188e-07
# iwts         3.692188e-07
# iwti         3.692188e-07
# iwt-         3.692188e-07
# iwst         3.692188e-07
# Bækkum       3.692188e-07
# iwqk         3.692188e-07
# iwqjei       3.692188e-07
# iwqjdt       3.692188e-07
# iwqit        3.692188e-07
# iwqLt        3.692188e-07
# iwnt         3.692188e-07
# iwnlJbg      3.692188e-07
# iwna         3.692188e-07
# iwmul        3.692188e-07
# iwml         3.692188e-07
# iwmi         3.692188e-07
# iwjujjex     3.692188e-07
# iwjtje       3.692188e-07
# iwjjlj       3.692188e-07
# iwjjl        3.692188e-07
# iwjji        3.692188e-07
# iwjOxL       3.692188e-07
# 09394        3.692188e-07
#
# [112846 rows x 1 columns]

# %%
print(', '.join(list(df_combo.sort_values(by=0, ascending=False)[:120].index)))
# Out:
# Dollar, Dane, Scandia, Wisconsin, Hilse, lowa, iaa, Kjere, Minnesota, Dakota, utvandringa, Registre, tømmermann, Prairie, Hvide, fea, enu, maaskee, Grimstad, Gasmann, Skare, Daler, ikkt, Landvik, isammen, Indianerne, væl, forældre, Sigdal, Christiana, daller, kas, Ivarson, Fayette, Tiid, Fjære, Skrive, Semmingsen, nske, Vede, iul, Grøgaard, troe, Sundhed, Stjerne, voxer, Potetes, flitig, New-, afbryde, fom, håber, godhed, Meidell, Åsland, Hendrik, linier, utvandrerne, Engebret, kostede, Emigranter, Amerikanere, gus, farmen, bte, hilset, Gulliksen, Bede, Tøi, Hiis, nke, Eielsen, Brev, Bi3, Sviin, Maaneden, ndag, Jøran, Gullik, Slutte, Sjursen, Guid, Slægtninger, Haugerud, befindende, Kittelsen, tilsende, Asle, ldre, hilses, ndt, herifra, kolt, Nyheder, Sjur, saadane, Hvede, søskende, gåt, Gudstjeneste, Earth, Aviserne, acre, Kreaturer, kait, Kreaturene, Haugrud, Ulvestad, Udkomme, Huus, Fortjeneste, Våar, Winnebago, Granvin, naturligviis, Midtvesten, udvandre, Ugers, Staar, dise

# %%
def testord(words, df = df_combo):
    words = words.split()
    res = dict()
    for w in words:
        if w in df_combo.index:
            res[w] = df_combo.transpose()[w]
    return pd.DataFrame.from_dict(res, orient='index').sort_values(by=0, ascending=False)

# %%
dt = testord("""arbeid arbeidet Arbeid Arbeide arbeide Arbeidet fattig
fattige Fattige Fattig Rige Rike rike Rigdom . , og i Reise Reisen reise reiste Sjø Hav Havet Sjøen 
Kone Mor Far Datter Sønn Søn Bibelen Gud Dans danse kultur Kultur Sang Sangen Kulturen""")
dt
# Out:
#                    0
# Reise     119.361751
# Arbeide   113.111249
# Kone       86.582010
# Reisen     59.346962
# Datter     52.756968
# Søn        44.241809
# Rige       22.381744
# Rigdom     17.277136
# Fattige    13.954610
# Hav         8.245906
# Dans        7.842910
# Havet       5.437670
# reise       4.689211
# Fattig      4.049329
# arbeide     3.796084
# Sang        3.599403
# Arbeidet    3.365024
# Sjø         3.239463
# reiste      3.149771
# Gud         2.855563
# fattige     1.603371
# Mor         1.396320
# og          1.263813
# arbeidet    1.114267
# Far         1.110026
# Bibelen     1.092831
# ,           1.032617
# i           1.010309
# fattig      0.932573
# .           0.681417
# Sangen      0.632090
# Sjøen       0.588993
# arbeid      0.383082
# Kultur      0.301345
# kultur      0.295616
# danse       0.276877
# Arbeid      0.143622
# rike        0.087112

# %%
dt = testord("""Hamar Namsos Trøndelag Rogaland Bergen Oslo Østfold Valdres og i , . Namdalen
Hallingdal Skien Telemark Vinje Lofoten Tromsø""")
dt
# Out:
#                    0
# Telemark    7.696769
# Hallingdal  4.829745
# Rogaland    4.672302
# Valdres     1.877072
# Bergen      1.473590
# og          1.263813
# ,           1.032617
# i           1.010309
# Oslo        0.710392
# Hamar       0.710019
# .           0.681417
# Trøndelag   0.472914
# Lofoten     0.431928
# Vinje       0.179141
# Skien       0.116110
# Tromsø      0.054906

# %%
dt = testord("""Neger Negre Hvit hvit neger svart svarte Svarte . , og i paa på Indianer indianere indianer Slaver Slave slaver Afrikaner 
Afrikanere afrikanere same Sami lapp Lapp Samer Lapper""")
dt
# Out:
#                    0
# Indianer   45.352482
# Negre      45.352482
# Slaver     32.394630
# Slave      22.676241
# paa         5.667077
# indianere   3.702243
# lapp        1.378495
# og          1.263813
# same        1.211014
# ,           1.032617
# i           1.010309
# Hvit        0.719881
# .           0.681417
# indianer    0.647893
# slaver      0.598055
# neger       0.498379
# på          0.348706
# svart       0.133862
# hvit        0.121915
# Svarte      0.089985
# svarte      0.048016
# Neger       0.000005

# %%
urns = list({x[0] for x in abrev})
urns
# Out:
# [2015012808002,
#  2007041601053,
#  2013010308006,
#  2010061503016,
#  2015082548012,
#  2007091801006,
#  2010082403023,
#  2007030801010,
#  2010051906100,
#  2013041608123,
#  2014072406038,
#  2007112704027,
#  2016052608061]

# %%
abrev
# Out:
# [[2010051906100, '', 'Fra Amerika til Norge', 1992],
#  [2007091801006, '', 'Fra Amerika til Norge', 1992],
#  [2007112704027, '', 'Fra Amerika til Norge', 1993],
#  [2010061503016, 'Sunde, Rasmus', 'utvandrarsoge frå Sogndal', 1994],
#  [2015082548012, 'Sunde, Rasmus', 'Long Prairie', 1994],
#  [2016052608061, 'Engen, Arnfinn', 'Utvandringshistorie og amerikabrev', 1975],
#  [2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2014072406038, '', 'Amerikabrev', 1989],
#  [2013010308006, '', 'Amerikabrev', 2000],
#  [2013041608123, 'Rodegard, Olaf', 'Amerikabrev', 1988],
#  [2015012808002, 'Kræmmer, Elias', 'Amerikanske breve', 1909],
#  [2007030801010, '', 'Amerikabrev', 1958],
#  [2007041601053, 'Johnson, Pål Espolin', 'Amerikabrev', 1985]]

# %%
nb.get_urnkonk('Dodge', {'urns' : urns, 'size' : 50, 'before' : 12, 'after' : 12})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>Pricident som kom ind nu er ikke enig med de Sydlige om</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>Handelens frihed. Dog kan han ikke forhindre dem at have Slaver i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>de statter som har været før men han vil heller ikke at</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>Handelen skal komme videre. Saa har de laavet at de vil dræbe</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>Blive end Stor Krig her i Landet i mellem fri Stattene og</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>Stattene , eller Stift Paa Norsk , og de haver allerede Begynt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030801010' target='_blank' style='text-decoration:none'>Amerikabrev, , 1958</a>
#                 </td>
#                 <td>Sindet og Modet , 82 a de 3221 - ne6dsie66 113680111 en</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>er nedtrykt 2 t sine Lænker og berøvet sin Frihed . 3</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030801010' target='_blank' style='text-decoration:none'>Amerikabrev, , 1958</a>
#                 </td>
#                 <td>erklærede at han aldrig vilde foretage det Mindste for at taas en</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>igjen naar han le ^ d bort ; en Anden eiede en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010051906100' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>; Frugten heraf er at den Fattige eller Arbeidsmanden kan gaae som</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>saalænge han lever og knapt sutinere ; Fattig er han fød og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112704027' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1993</a>
#                 </td>
#                 <td>Egen Herre men i Norge maatte jeg gaae under Commando ligesom en</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>. Det andet Sp ? ? rgsmaal var om jeg har betalt</td>
#             </tr>
# </table>

# %%
combo.transpose()[df_combo.sort_values(by=0, ascending=False)[:20].index].transpose()
# Out:
#                  brev           ref
# Dollar       0.000315  1.067757e-07
# Dane         0.000166  1.067757e-07
# Scandia      0.000163  1.067757e-07
# Wisconsin    0.000743  5.338783e-07
# Hilse        0.000135  1.067757e-07
# lowa         0.000323  3.203270e-07
# iaa          0.000199  2.135513e-07
# Kjere        0.000089  1.067757e-07
# Minnesota    0.000463  6.406540e-07
# Dakota       0.000073  1.067757e-07
# utvandringa  0.000065  1.067757e-07
# Registre     0.000127  2.135513e-07
# tømmermann   0.000185  3.203270e-07
# Prairie      0.000306  5.338783e-07
# Hvide        0.000177  3.203270e-07
# fea          0.000057  1.067757e-07
# enu          0.000056  1.067757e-07
# maaskee      0.000054  1.067757e-07
# Grimstad     0.001176  2.349065e-06
# Gasmann      0.000053  1.067757e-07

# %%
df_combo[:5]
# Out:
#            0
# ,   1.032617
# .   0.681417
# og  1.263813
# at  2.278370
# i   1.010309

# %%
nb.metadata(urns)
# Out:
# [[2015012808002,
#   'Kræmmer, Elias',
#   1909,
#   'Amerikanske breve',
#   'Schibsted',
#   'nob',
#   ''],
#  [2007041601053,
#   'Johnson, Pål Espolin',
#   1985,
#   'Amerikabrev',
#   'Cappelen',
#   'nob',
#   ''],
#  [2013010308006, '', 2000, 'Amerikabrev', 'Seminaret', 'nob', ''],
#  [2010061503016,
#   'Sunde, Rasmus',
#   1994,
#   'utvandrarsoge frå Sogndal',
#   '[Sogndal kommune, Kulturkontoret]',
#   'nno',
#   ''],
#  [2015082548012,
#   'Sunde, Rasmus',
#   1994,
#   'Long Prairie',
#   'Vik lokalhistoriske arkiv',
#   'nno',
#   ''],
#  [2007091801006,
#   '',
#   1992,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2010082403023,
#   'Evensen, Erik Aalvik',
#   1996,
#   'Amerika-brevene',
#   'Selskapet for Grimstad bys vel',
#   'nob',
#   ''],
#  [2007030801010, '', 1958, 'Amerikabrev', 'Aschehoug', 'nob', 'eng'],
#  [2010051906100,
#   '',
#   1992,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2013041608123,
#   'Rodegard, Olaf',
#   1988,
#   'Amerikabrev',
#   'O. Rodegard',
#   'nob',
#   ''],
#  [2014072406038, '', 1989, 'Amerikabrev', 'Forlaget Lister', 'nob', ''],
#  [2007112704027,
#   '',
#   1993,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2016052608061,
#   'Engen, Arnfinn',
#   1975,
#   'Utvandringshistorie og amerikabrev',
#   '',
#   'nob',
#   '']]

# %%
test_words = """Arbeid Arbeide Arbeidet 
Fattige Fattig Rige Rigdom Reise Reisen Sjø Hav Havet Sjøen 
Kone Mor Far Datter Sønn Søn Sønn Bibel Bibelen Gud Dans Danse Kultur Sang Sangen Kulturen 
Hamar Namsos Trøndelag Rogaland Bergen Oslo Østfold Kristiansand Agder Vestfold Østfold
Valdres Namdalen Troms Finnmark Møre Romsdal Oppland Hedmark Mjøsa Hamar Lillehammer
Korn Fisk Kornet Fisken Åker Åkeren Åkren Jord Jorda Jorden Klær Kjole Skjorte Jakke Jakken
Hallingdal Skien Telemark Vinje Lofoten Tromsø Neger Negre Hvit Hvite hvite 
Svarte Indianer indianere indianer Slaver Slave slaver Afrikaner 
Afrikanere afrikanere Lapp Samer Lapper dollar cents Dollar Cents
Iowa Minnesota Wisconsin Fargo Fergus Minneapolis Dodge Dakota Grimstad Arendal"""
low_test = ' '.join([x.lower() for x in test_words.split()])
test_words = low_test + test_words

# %%
import matplotlib.pyplot as plt

# %%
G = dict()
for u in urns:
    G[u] = nb.make_network_graph(u, wordbag= test_words.split())

# %%
u = list(G.keys())[8]
ugraph = G[u]
print(' '.join([str(x) for x in nb.metadata(u)[0]]))
gnl.draw_graph_centrality2(ugraph, gnl.mcommunity(ugraph), fontsize=8, k=.9, l_alpha=0.8, multi=4000)
# Out:
# 2010051906100  1992 Fra Amerika til Norge Solum;Oslo : Solum, 1992-2011 nob

# %%
i = 1
for s in gnl.mcommunity(ugraph):
    print(i, ' ==> ', ', '.join(s))
    i += 1
# Out:
# 1  ==>  Dodge, Oslo, Cents, Hedmark, Kristiansand, Vestfold, Oppland, arbeid, Trøndelag, Iowa, Finnmark, Minneapolis, mor, Valdres, Minnesota, Skien, Wisconsin, Agder, Telemark, Dakota, Arendal
# 2  ==>  kornet, korn, jorden, Bibel, Grimstad, kone, Kjole, Rige, gud, danse, far, Reisen, søn, Havet, dollar, datter, hav, Reise
# 3  ==>  arbeidet, Fattig, Fattige, Arbeidet, jord, Jord, Dollar, reise, Slave, reisen, Arbeide, arbeide, Jorden, slave, Far, fattig, Sang, Dans, rige, skjorte, fattige
# 4  ==>  Søn, havet, Korn, Gud, Mor, Kone, rigdom, Hav, Datter, Kornet, sjøen, Slaver, cents, Bergen, Fisk, bibelen, bibel

# %%
uclique = gnl.make_cliques_from_graph(ugraph)
for k in uclique[1]:
    print(k, ' --> ', ', '.join(uclique[1][k]))
# Out:
# (3, 1)  -->  arbeidet, kornet, jorden, Dodge, Arbeidet, Fattige, Fattig, Cents, Oslo, gud, jord, Hedmark, Hav, danse, Reisen, Jord, Dollar, søn, Kristiansand, Havet, cents, bibelen, hav, reise, korn, rigdom, Kone, reisen, Slave, Oppland, Arbeide, arbeid, Kornet, Iowa, arbeide, Arendal, Jorden, Fisk, slave, Reise, Korn, mor, kone, fattig, Valdres, Grimstad, Minnesota, Skien, Wisconsin, far, Gud, Agder, datter, bibel, Telemark, Søn, Mor, Dans, Rige, rige, Dakota, Datter, dollar, Slaver, Bergen, havet, fattige
# (4, 1)  -->  arbeidet, kornet, jorden, Dodge, Arbeidet, Fattige, Fattig, Cents, Oslo, gud, Hedmark, Hav, danse, Reisen, Jord, Dollar, søn, Havet, cents, hav, reise, korn, Kone, reisen, Slave, Oppland, Arbeide, arbeid, Kornet, arbeide, Arendal, Jorden, Reise, Korn, mor, kone, fattig, Valdres, Minnesota, Wisconsin, Gud, Agder, datter, Telemark, Søn, Mor, Dans, Rige, rige, Datter, dollar, Bergen, havet, fattige
# (5, 1)  -->  arbeidet, kornet, jorden, Arbeidet, Fattige, Fattig, Cents, gud, Hav, Reisen, Jord, Dollar, søn, Havet, cents, hav, reise, korn, Kone, reisen, Slave, Arbeide, arbeid, Kornet, arbeide, Arendal, Jorden, Reise, Korn, kone, fattig, Minnesota, Wisconsin, Gud, datter, Søn, Rige, rige, Datter, dollar, Bergen, havet
# (5, 2)  -->  Oslo, mor, Valdres, Oppland, Minnesota, Hedmark, Wisconsin, Agder, Telemark
# (6, 1)  -->  arbeidet, Arbeidet, Fattige, Cents, gud, Hav, Reisen, Jord, Dollar, søn, Havet, cents, hav, reise, korn, Kone, reisen, Arbeide, Kornet, arbeide, Jorden, Reise, Korn, kone, fattig, Minnesota, Wisconsin, Gud, datter, Søn, Bergen, Rige, Datter, dollar, Arendal, havet
# (6, 2)  -->  Arbeidet, Fattige, Fattig, fattig, Arbeide, Slave
# (7, 1)  -->  arbeidet, Korn, Arbeidet, Fattige, kone, fattig, gud, Jorden, Cents, Minnesota, Hav, Wisconsin, Reisen, Jord, Dollar, Gud, Havet, søn, datter, hav, Søn, reise, korn, Kone, Arbeide, Datter, dollar, arbeide, Bergen, havet, Reise
# (8, 1)  -->  arbeidet, Arbeidet, Fattige, kone, fattig, Jorden, gud, Minnesota, Wisconsin, Reisen, Jord, Dollar, Gud, datter, hav, Søn, reise, korn, Kone, Arbeide, Datter, dollar, arbeide, Bergen, havet, Reise
# (9, 1)  -->  arbeidet, Arbeidet, Fattige, kone, Wisconsin, Reisen, Jord, Dollar, Gud, Søn, reise, havet, Kone, Arbeide, dollar, arbeide, Jorden, Reise
# (10, 1)  -->  arbeidet, Arbeidet, Reisen, Jord, Dollar, Gud, Søn, reise, Kone, Arbeide, arbeide, Jorden, Reise

# %%
uforest = gnl.forest(uclique[2])

# %%
gnl.draw_forest(uforest, 2)
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
nb.central_betweenness_characters(ugraph, n=20)
# Out:
# [('Wisconsin', 0.16470005351574427),
#  ('Reise', 0.15972921095932924),
#  ('Minnesota', 0.131084544615166),
#  ('Arbeide', 0.08538171556691926),
#  ('Gud', 0.07658714435629768),
#  ('Kone', 0.06941570957793293),
#  ('reise', 0.06125452001043918),
#  ('arbeide', 0.05806832284678726),
#  ('Dollar', 0.056034161434660924),
#  ('kone', 0.05353717887966209),
#  ('Bergen', 0.051856677138464306),
#  ('Reisen', 0.045163524435488336),
#  ('arbeidet', 0.03817521807703695),
#  ('Oppland', 0.0345422882484802),
#  ('Søn', 0.031348474182618574),
#  ('Telemark', 0.026759217657896534),
#  ('mor', 0.022898438650918236),
#  ('dollar', 0.018247746960194086),
#  ('Jord', 0.017329710025850834),
#  ('Arbeidet', 0.013841069983963056)]
