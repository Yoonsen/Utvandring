# %%
# !pip install python-louvain
# Out:
# ...
#   Running setup.py bdist_wheel for python-louvain: started
#   Running setup.py bdist_wheel for python-louvain: finished with status 'done'
#   Stored in directory: C:\Users\larsj\AppData\Local\pip\Cache\wheels\c3\b0\db\198c7453d5169907dbdbb090eebc0c6839f75e36b09c6dc7aa
# Successfully built python-louvain
# ...
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 18.0
#     Uninstalling pip-18.0:
#       Successfully uninstalled pip-18.0
# ...

# %%
from module_update import update

# %%
update('graph_networkx_louvain')
update('nbtext')
# Out:
# Updated file graph_networkx_louvain.py
# Updated file nbtext.py

# %%
import graph_networkx_louvain as gnl

# %%
import networkx as nx

# %%
import imp

# %%
imp.reload(gnl)
# Out:
# <module 'graph_networkx_louvain' from 'C:\\Users\\larsj\\Documents\\GitHub\\Utvandring\\graph_networkx_louvain.py'>

# %%
import nbtext as nb

# %%
import requests
import pandas as pd

# %%
from nbtext import collocation, collocation_data

# %%
from nbtext import urn_coll

# %%
urner = nb.pure_urn("""Logg på
Sortering : Visning :
(api 765 ms)
391 treff i bøker
Fra Amerika til Norge : norske utvandrerbrev. 6 : 1895-1904
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
2010
(api)
id: 647fbd26d178038e0bfdd38e39fd003e
urn: URN:NBN:no-nb_digibok_2015062208208
isDigital: true
viewability: ALL
allowedFrom: NB
contentClasses:
restricted
legaldeposit
jp2
Fra Amerika til Norge : norske utvandrerbrev. 5 : 1885-1894
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
2009
(api)
id: 2683ed83bf501e0c481aa1b396698250
urn: URN:NBN:no-nb_digibok_2015070908050
isDigital: true
viewability: ALL
allowedFrom: NB
contentClasses:
restricted
legaldeposit
jp2
Fra Amerika til Norge : norske utvandrerbrev. 1 : 1838-1857
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
1992
(api)
id: 051958fa14d14e215b88b962bca7ccd1
urn: URN:NBN:no-nb_digibok_2010051906100
isDigital: true
viewability: ALL
allowedFrom: NORWAY
contentClasses:
legaldeposit
bokhylla
jp2
Fra Amerika til Norge : norske utvandrerbrev. 4 : 1875-1884
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
2002
(api)
id: d1e750cdf27ae7975f962b42cb391b2a
urn: URN:NBN:no-nb_digibok_2009042900008
isDigital: true
viewability: ALL
allowedFrom: NB
contentClasses:
restricted
legaldeposit
jp2
Fra Amerika til Norge : norske utvandrerbrev. 7 : 1905-1914
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
2011
(api)
id: 90e6a6b19c54f17158eb679633b924dc
urn: URN:NBN:no-nb_digibok_2015070908064
isDigital: true
viewability: ALL
allowedFrom: NB
contentClasses:
restricted
legaldeposit
jp2
Fra Amerika til Norge : norske utvandrerbrev. 3 : 1869-1874 : (med et tillegg av brev 1845-1867)
Kjærheim, Steinar | Øverland, Orm | Kjeldeskriftfondet
1993
(api)
id: 46b59f7be3a49dfe4427da93a9a5a252
urn: URN:NBN:no-nb_digibok_2007112704027
isDigital: true
viewability: ALL
allowedFrom: NORWAY
contentClasses:
legaldeposit
bokhylla
jp2
Fra Amerika til Norge : norske utvandrerbrev. 2 : 1858-1868 : (med et tillegg av brev 1836-1857)""")

# %%
nyebrev = nb.metadata(urner)
# Out:
# [[2015062208208,
#   '',
#   2010,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2015070908050,
#   '',
#   2009,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2010051906100,
#   '',
#   1992,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2009042900008,
#   '',
#   2002,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2015070908064,
#   '',
#   2011,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2007112704027,
#   '',
#   1993,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   '']]

# %%
abrev = nb.get_urn({'title':'fra amerika til%', 'limit':100}) 
abrev
# Out:
# [[2007091801006, '', 'Fra Amerika til Norge', 1992],
#  [2010051906100, '', 'Fra Amerika til Norge', 1992],
#  [2007112704027, '', 'Fra Amerika til Norge', 1993]]

# %%
abrev2 = nb.get_urn({'author':"sunde%rasm%"})
abrev2[1:]
# Out:
# [[2016072248034, 'Sunde, Rasmus', 'stad skal ein vera', 1989],
#  [2015082548012, 'Sunde, Rasmus', 'Long Prairie', 1994]]

# %%
abrev3 = nb.get_urn({'title':'%amerika%brev%', 'limit':100}) 
abrev3[:5]
# Out:
# [[2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2016052608061, 'Engen, Arnfinn', 'Utvandringshistorie og amerikabrev', 1975],
#  [2013041608123, 'Rodegard, Olaf', 'Amerikabrev', 1988],
#  [2007030801010, '', 'Amerikabrev', 1958],
#  [2014072406038, '', 'Amerikabrev', 1989]]

# %%
abrev = abrev +  abrev3

# %%
dbrev = nb.get_urn({'ddk':'304.8%', 'limit':100})
dbrev
# Out:
# [[2013110608132, 'Flå, Vibeke', 'Utvandring og intern flytting', 1995],
#  [2015112708157, 'Standal, Ragnar', 'Mot nye heimland', 1985],
#  [2014121108068, '', 'Norwegian-American essays 1996', 1996],
#  [2008041804067, 'Semmingsen, Ingrid', 'Veien mot vest', 1950],
#  [2008020600020, '', 'Frå Sogn til Amerika', 1994],
#  [2011022808164, '', 'Norsk emigrantlitteratur', 2000],
#  [2008101004055, '', 'Utvandring til Amerika', 2000],
#  [2008012800046,
#   'Skretting, Harald',
#   'I far sine fotefar - 75 år etter',
#   1994],
#  [2012061406142, 'Ottosen, Rune', 'Mitt nye hjemland', 1987],
#  [2015060508068, '', 'Norsk emigrantlitteratur', 2000],
#  [2014071808096, 'Ryningen, Alfred', 'Valle kommune', 2000],
#  [2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2014022408011, '', 'Eit blidare tilvere?', 1986],
#  [2009042104066,
#   'Skretting, Harald',
#   "In my father's footsteps - 75 years later",
#   2000],
# ...

# %%
dbrev = nb.get_urn({'yearfrom':1850, 'yearto':1940, 'limit':200})
dbrev[:5]
# Out:
# [[2014050805171,
#   '',
#   'Rapport om elektroniske betalingssystemer i Norden',
#   1984],
#  [2010111508048, 'Kent, Larry', 'Dødsbåten', 1991],
#  [2015091848041, '', 'Vokenatt', 1932],
#  [2016012008125,
#   'Berntsen, Randi Tønnessen',
#   'Kroppsøvingsprosjektet. Rapport nr. 1, Kroppsøving i Norge, Sverige og Danmark',
#   1980],
#  [2016072609007,
#   '',
#   'Innstilling om etterutdanning for skoleledere i grunnskolen',
#   1974]]

# %%
fs = [nb.get_freq(u[0], top=0, cutoff=0) for u in abrev]
from collections import Counter
fsum = Counter()
for f in fs:
    fsum += f

# %%
gs = [nb.get_freq(u[0], top=0, cutoff=0) for u in dbrev]
from collections import Counter
dsum = Counter()
for f in gs:
    dsum += f

# %%
brev = pd.DataFrame.from_dict(fsum, orient='index')
brev.columns = ['brev']
ref = pd.DataFrame.from_dict(dsum, orient='index')
ref.columns = ['ref']
nb.normalize_corpus_dataframe(brev)
nb.normalize_corpus_dataframe(ref)
# Out:
# True

# %%
combo = (brev.join(ref)).fillna(0.8)

# %%
pd.DataFrame((combo['brev']/combo['ref'])).sort_values(by=0, ascending=False)
# Out:
#                       0
# Daler      2.139983e+03
# Registre   1.388712e+03
# Forældre   1.161054e+03
# Fjære      1.145877e+03
# Søskende   1.085169e+03
# ikkt       1.054814e+03
# Kjere      9.713397e+02
# Heste      8.802766e+02
# Linier     8.423336e+02
# forlod     8.119792e+02
# modtog     7.702420e+02
# Daller     7.512705e+02
# Landvik    7.006799e+02
# Hilset     6.905618e+02
# forige     6.526188e+02
# Lindtner   5.994987e+02
# Angaaende  5.919101e+02
# Sødskende  5.843215e+02
# Cent       5.729386e+02
# Marts      5.615557e+02
# haabe      5.615557e+02
# Maaneden   5.539671e+02
# syge       5.236128e+02
# Hveden     5.008470e+02
# Sando      5.008470e+02
# dlg        5.008470e+02
# kjøbt      4.856698e+02
# Hvide      4.856698e+02
# Lan        4.780812e+02
# væl        4.780812e+02
# ...                 ...
# Inman-     9.003409e-07
# Injgoskl   9.003409e-07
# Injejt     9.003409e-07
# Islaiid    9.003409e-07
# særdel     9.003409e-07
# Itaad      9.003409e-07
# ...

# %%
df_combo = pd.DataFrame(combo['brev']**1.06/combo['ref'])

# %%
pd.DataFrame(combo['brev']**1.06/combo['ref']).sort_values(by=0, ascending=False)
# Out:
#                       0
# Daler      1.284917e+03
# Registre   8.124733e+02
# Fjære      7.299023e+02
# Forældre   6.720226e+02
# Søskende   6.255574e+02
# ikkt       6.070251e+02
# Kjere      5.562289e+02
# Heste      5.011139e+02
# Linier     4.782482e+02
# forlod     4.599999e+02
# modtog     4.534472e+02
# Daller     4.236276e+02
# Landvik    4.202602e+02
# Hilset     3.874314e+02
# forige     3.649046e+02
# Lindtner   3.476622e+02
# Cent       3.313573e+02
# Angaaende  3.290268e+02
# Sødskende  3.245571e+02
# Marts      3.111692e+02
# haabe      3.111692e+02
# Maaneden   3.067137e+02
# Hvide      2.899248e+02
# syge       2.889289e+02
# Maaned     2.786744e+02
# kjøbt      2.781144e+02
# Sando      2.756307e+02
# dlg        2.756307e+02
# Hveden     2.756307e+02
# væl        2.623687e+02
# ...                 ...
# Inman-     3.853513e-07
# Injgoskl   3.853513e-07
# Injejt     3.853513e-07
# Islaiid    3.853513e-07
# særdel     3.853513e-07
# Itaad      3.853513e-07
# ...

# %%
print(', '.join(list(df_combo.sort_values(by=0, ascending=False)[:120].index)))
# Out:
# Daler, Registre, Fjære, Forældre, Søskende, ikkt, Kjere, Heste, Linier, forlod, modtog, Daller, Landvik, Hilset, forige, Lindtner, Cent, Angaaende, Sødskende, Marts, haabe, Maaneden, Hvide, syge, Maaned, kjøbt, Sando, dlg, Hveden, væl, Lan, Nyheder, Flesberg, søskende, Christiana, Uger, Furuseth, Doll, Nærheden, Maaneder, Veir, Eker, Mile, Byg, utvandrere, Folkedal, hilset, Thid, tildeels, Bekjente, Vores, hiis, Meberg, Ørbæk, samen, håber, Præst, godhed, skjøndt, Lidet, Piger, Helbred, linier, Catharine, Høst, utvandrerne, Feber, Floden, dise, haaber, Skare, flyttede, utvandringa, Koe, ijen, Næsheim, dete, Grimstad, kjøbte, Eder, Snee, Hende, Takke, maade, forladt, ugen, Sviin, syg, Præster, Kjærlig, Gjen, Velsignelse, komer, Torgrim, Tusinde, Sidste, Vaaren, Bliver, Reise, Brev, Christo, Strenge, blodt, deels, Wærenskjold, Herbrand, Vestover, Meidell, Pennen, heromkring, Fragt, forlade, Broder, Penge, herover, båge, Breve, Haver, Landsmænd, Eureka

# %%
def testord(words, exp=1.0):
    """Wrapper for the computation of letters to reference"""
    words = words.split()
    res = dict()
    df_combo = pd.DataFrame(combo['brev']**exp/combo['ref']).sort_values(by=0, ascending=False)
    for w in words:
        if w in df_combo.index:
            res[w] = df_combo.transpose()[w]
    return pd.DataFrame.from_dict(res, orient='index').sort_values(by=0, ascending=False)

# %%
dt = testord("""arbeid arbeidet Arbeid Arbeide arbeide Arbeidet fattig
fattige Fattige Fattig Rige Rike rike Rigdom . , og i Reise Reisen reise reiste Sjø Hav Havet Sjøen 
Kone Mor Far Datter Sønn Søn Bibelen Gud Dans danse kultur Kultur Sang Sangen Kulturen""",1)
dt
# Out:
#                    0
# Reise     190.478635
# Arbeide   149.169011
# Kone       99.410575
# Reisen     36.791672
# Fattige    20.944290
# Rige       18.272824
# Havet       9.588133
# Fattig      8.415116
# Hav         6.080600
# Dans        5.339246
# Sang        5.178533
# reise       4.769223
# reiste      3.551055
# Arbeidet    3.469617
# arbeide     2.428331
# Søn         2.097745
# Mor         2.071413
# Gud         2.013186
# Sjø         1.683023
# Datter      1.459464
# Far         1.392847
# Sangen      1.282303
# Sjøen       1.262267
# fattige     1.254268
# og          1.200016
# ,           1.136723
# arbeidet    0.928565
# i           0.926091
# fattig      0.913641
# Arbeid      0.904311
# .           0.877951
# Bibelen     0.561008
# danse       0.525945
# arbeid      0.412682
# Kultur      0.363897
# kultur      0.253245
# rike        0.124668
# Rigdom      0.000013

# %%
dt = testord("""Hamar Namsos Trøndelag Rogaland Bergen Oslo Østfold Valdres og i , . Namdalen
Hallingdal Skien Telemark Vinje Lofoten Tromsø""")
dt
# Out:
#                    0
# Telemark    8.884156
# Valdres     7.405302
# Hallingdal  5.632976
# Rogaland    5.205227
# og          1.200016
# ,           1.136723
# i           0.926091
# .           0.877951
# Bergen      0.832440
# Vinje       0.810345
# Lofoten     0.538567
# Hamar       0.529490
# Trøndelag   0.474091
# Skien       0.461102
# Oslo        0.278098
# Tromsø      0.029018

# %%
dt = testord("""Neger Negre Hvit hvit neger svart svarte Svarte . , og i paa på Indianer indianere indianer Slaver Slave slaver Afrikaner 
Afrikanere afrikanere same Sami lapp Lapp Samer Lapper""")
dt
# Out:
#                    0
# Indianer   23.562326
# Slave      23.562326
# Slaver     11.220155
# paa         9.082439
# Neger       4.039256
# lapp        2.692837
# indianere   1.632023
# same        1.559244
# indianer    1.553560
# og          1.200016
# ,           1.136723
# i           0.926091
# .           0.877951
# neger       0.807851
# Svarte      0.531481
# på          0.359690
# slaver      0.306004
# svart       0.119363
# Hvit        0.119152
# hvit        0.064028
# svarte      0.041936
# Negre       0.000006

# %%
urns = list({x[0] for x in abrev})
urns
# Out:
# [2015012808002,
#  2007041601053,
#  2013010308006,
#  2010061503016,
#  2015082548012,
#  2007091801006,
#  2010082403023,
#  2007030801010,
#  2010051906100,
#  2013041608123,
#  2014072406038,
#  2007112704027,
#  2016052608061]

# %%
abrev
# Out:
# [[2010051906100, '', 'Fra Amerika til Norge', 1992],
#  [2007091801006, '', 'Fra Amerika til Norge', 1992],
#  [2007112704027, '', 'Fra Amerika til Norge', 1993],
#  [2010061503016, 'Sunde, Rasmus', 'utvandrarsoge frå Sogndal', 1994],
#  [2015082548012, 'Sunde, Rasmus', 'Long Prairie', 1994],
#  [2016052608061, 'Engen, Arnfinn', 'Utvandringshistorie og amerikabrev', 1975],
#  [2010082403023, 'Evensen, Erik Aalvik', 'Amerika-brevene', 1996],
#  [2014072406038, '', 'Amerikabrev', 1989],
#  [2013010308006, '', 'Amerikabrev', 2000],
#  [2013041608123, 'Rodegard, Olaf', 'Amerikabrev', 1988],
#  [2015012808002, 'Kræmmer, Elias', 'Amerikanske breve', 1909],
#  [2007030801010, '', 'Amerikabrev', 1958],
#  [2007041601053, 'Johnson, Pål Espolin', 'Amerikabrev', 1985]]

# %%
nb.get_urnkonk('Dodge', {'urns' : urns, 'size' : 50, 'before' : 12, 'after' : 12})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>Pricident som kom ind nu er ikke enig med de Sydlige om</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>Handelens frihed. Dog kan han ikke forhindre dem at have Slaver i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>de statter som har været før men han vil heller ikke at</td>
#                 <td>Slave</td>
#                 <td style='text-align:left'>Handelen skal komme videre. Saa har de laavet at de vil dræbe</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
combo.transpose()[df_combo.sort_values(by=0, ascending=False)[:20].index].transpose()
# Out:
#                  brev           ref
# Dollar       0.000315  1.067757e-07
# Dane         0.000166  1.067757e-07
# Scandia      0.000163  1.067757e-07
# Wisconsin    0.000743  5.338783e-07
# Hilse        0.000135  1.067757e-07
# lowa         0.000323  3.203270e-07
# iaa          0.000199  2.135513e-07
# Kjere        0.000089  1.067757e-07
# Minnesota    0.000463  6.406540e-07
# Dakota       0.000073  1.067757e-07
# utvandringa  0.000065  1.067757e-07
# Registre     0.000127  2.135513e-07
# tømmermann   0.000185  3.203270e-07
# Prairie      0.000306  5.338783e-07
# Hvide        0.000177  3.203270e-07
# fea          0.000057  1.067757e-07
# enu          0.000056  1.067757e-07
# maaskee      0.000054  1.067757e-07
# Grimstad     0.001176  2.349065e-06
# Gasmann      0.000053  1.067757e-07

# %%
df_combo[:5]
# Out:
#            0
# ,   1.032617
# .   0.681417
# og  1.263813
# at  2.278370
# i   1.010309

# %%
urns = [x[0] for x in abrev]
nb.metadata(urns)
# Out:
# [[2007112704027,
#   '',
#   1993,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2010051906100,
#   '',
#   1992,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2007091801006,
#   '',
#   1992,
#   'Fra Amerika til Norge',
#   'Solum;Oslo : Solum, 1992-2011',
#   'nob',
#   ''],
#  [2010082403023,
#   'Evensen, Erik Aalvik',
#   1996,
#   'Amerika-brevene',
#   'Selskapet for Grimstad bys vel',
#   'nob',
#   ''],
#  [2016052608061,
#   'Engen, Arnfinn',
#   1975,
#   'Utvandringshistorie og amerikabrev',
#   '',
#   'nob',
#   ''],
#  [2013041608123,
#   'Rodegard, Olaf',
#   1988,
#   'Amerikabrev',
#   'O. Rodegard',
#   'nob',
#   ''],
#  [2007030801010, '', 1958, 'Amerikabrev', 'Aschehoug', 'nob', 'eng'],
#  [2014072406038, '', 1989, 'Amerikabrev', 'Forlaget Lister', 'nob', ''],
#  [2015012808002,
#   'Kræmmer, Elias',
#   1909,
#   'Amerikanske breve',
#   'Schibsted',
#   'nob',
#   ''],
# ...

# %%
import matplotlib.pyplot as plt

# %%
test_words = """Arbeid Arbeide Arbeidet 
Fattige Fattig Rige Rigdom Reise Reisen Sjø Hav Havet Sjøen 
Kone Mor Far Datter Sønn Søn Sønn Bibel Bibelen Gud Dans Danse Kultur Sang Sangen Kulturen 
Hamar Namsos Trøndelag Rogaland Bergen Oslo Østfold Kristiansand Agder Vestfold Østfold
Valdres Namdalen Troms Finnmark Møre Romsdal Oppland Hedmark Mjøsa Hamar Lillehammer
Korn Fisk Kornet Fisken Åker Åkeren Åkren Jord Jorda Jorden Klær Kjole Skjorte Jakke Jakken
Hallingdal Skien Telemark Vinje Lofoten Tromsø Neger Negre Hvit Hvite Indianer Slaver Slave Afrikaner 
Afrikanere Dollar Cents
Iowa Minnesota Wisconsin Fargo Fergus Minneapolis Dodge Dakota Grimstad Arendal"""
low_test = ' '.join([x.lower() for x in test_words.split()])
test_words = low_test + test_words

# %%
gnl.draw_graph_centrality2(ugraph, gnl.mcommunity(Gall), h=20, v=15, fontsize=14, k=1.9, l_alpha=0.8, deltax=0.05,deltay=0.02)

# %%
import seaborn as sns
def draw_graph_centrality2(G, Subsets=[],  h=15, v=10, deltax=0, deltay=0, fontsize=18, k=0.2, arrows=False, 
                           node_alpha=0.3, l_alpha=1, node_color='blue', centrality=nx.degree_centrality, 
                           font_color='black', 
                           threshold=0.01, 
                           multi=3000,
                          edge_color='olive',
                          colstart=0.2,
                          coldark=0.5):
    
    from pylab import rcParams
    import matplotlib.pyplot as plt
    from matplotlib import colors as mcolors


    colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
    node_dict = centrality(G)
    subnodes = dict({x:node_dict[x] for x in node_dict if node_dict[x] >= threshold})
    #print(subnodes)
    x, y = rcParams['figure.figsize']
    rcParams['figure.figsize'] = h, v
    
    ax = plt.subplot()
    ax.set_xticks([])
    ax.set_yticks([])
    #G = G.subgraph(subnodes)
    glob_col = sns.hls_palette(len(G), h=colstart, l=coldark)[0]
    pos = nx.spring_layout(G, k=k)
    labelpos = dict({k:(pos[k][0]+ deltax, pos[k][1] + deltay) for k in pos })
    #print(labelpos)
    #print(pos)
    if l_alpha <= 1:
        nx.draw_networkx_labels(G, labelpos, font_size=fontsize, alpha = l_alpha, font_color = font_color)
    sub_color = 0
    if Subsets != []:
        i = 0
        colpalette = sns.hls_palette(len(Subsets), h=colstart, l=coldark)
        #print(colpalette)
        for Sub in Subsets:
            sublist = dict({x:subnodes[x] for x in subnodes if x in Sub})
            #print(sublist)
            #sub_col = list(colors.values())[np.random.randint(20,100)]
            sub_col= colpalette[i]
            #print(i, sub_col, sublist.keys())
            #print(i, sub_col)
            nx.draw_networkx_nodes(G, pos, alpha=node_alpha, node_color = [sub_col], nodelist= [x for x in sublist.keys()], node_size = [v * multi for v in sublist.values()])
            i += 1
    else:
        nx.draw_networkx_nodes(G, pos, alpha=node_alpha, node_color= glob_col,  nodelist = subnodes.keys(), node_size = [v * multi for v in subnodes.values()])
        True
        
    nx.draw_networkx_edges(G, pos, alpha=0.1, arrows = arrows, edge_color = edge_color)

    rcParams['figure.figsize'] = x, y

# %%
ugraph = nx.compose_all([G[u] for u in G])

# %%
G = dict()
for u in urns:
    G[u] = nb.make_network_graph(u, wordbag= test_words.split())

# %%
u = list(G.keys())[9]
ugraph = G[u]
print(' '.join([str(x) for x in nb.metadata(u)[0]]))
draw_graph_centrality2(ugraph, gnl.mcommunity(ugraph), fontsize=16, k=0.5, l_alpha=0.8, multi=4000, deltax=0.02, deltay=0.07)
# Out:
# 2013010308006  2000 Amerikabrev Seminaret nob

# %%
i = 1
for s in gnl.mcommunity(ugraph):
    print(i, ' ==> ', ', '.join(s))
    i += 1
# Out:
# 1  ==>  hvit, Korn, Skjorte, Fattige, jorda, Telemark, Åkeren, sjø, sjøen, dans, Jorden, Fisk, Slaver, arbeidet, sangen, Dollar, Dans, korn, Arendal, Kjole, Fattig, Skien, Agder, Fergus, sang, Bibelen, Danse, Fargo, Lillehammer, Reisen, Oppland, Cents, hvite, rige, Negre, Finnmark, Hedmark, far, jord, åker, søn, fisken, cents, Sang, jorden, Reise, Minneapolis, Sangen, Kristiansand, Rigdom, åkeren, danse, skjorte, Bergen, Fisken, Dakota, rigdom, Dodge, Søn, Vinje, Mor, Bibel, Kone, Sjøen, Kornet, Gud, indianer, hav, Slave, slave, Rogaland, bibel, Havet, klær, Datter, Hav, Rige, kornet, reise, Neger, havet, gud, arbeid, Arbeidet, Far, Vestfold, kjole, bibelen, Hallingdal, Oslo, Arbeide, Wisconsin, Indianer, negre, mor, fattige, Valdres, Jord, fattig, fisk, reisen, Trøndelag, slaver, arbeide, dollar
# 2  ==>  Grimstad, Sjø, Minnesota, kone, sønn, Iowa, datter, kultur
# 3  ==>  Hamar, Lofoten

# %%
uclique = gnl.make_cliques_from_graph(ugraph)
for k in uclique[1]:
    print(k, ' --> ', ', '.join(uclique[1][k]))
# Out:
# (3, 1)  -->  Dakota, rigdom, Dodge, Minnesota, Søn, hvit, Korn, Skjorte, Fattige, jorda, Telemark, Åkeren, sjø, Mor, sjøen, dans, Kone, Jorden, Fisk, Slaver, Sjøen, arbeidet, sangen, Kornet, Dollar, Gud, korn, Dans, hav, Arendal, sønn, Slave, Kjole, Iowa, slave, Rogaland, bibel, Fattig, Skien, Havet, klær, Datter, Agder, Hav, Fergus, sang, Bibelen, Danse, Rige, Fargo, kornet, Lillehammer, Reisen, reise, Neger, Oppland, Cents, hvite, rige, arbeid, gud, kone, havet, Arbeidet, Negre, Far, Vestfold, Finnmark, kjole, Hedmark, bibelen, far, Oslo, Hallingdal, jord, Arbeide, Wisconsin, åker, søn, fisken, mor, cents, Sang, jorden, Reise, Minneapolis, Sangen, fattige, Kristiansand, Grimstad, Rigdom, Valdres, Jord, fattig, danse, åkeren, reisen, fisk, skjorte, Trøndelag, slaver, Bergen, arbeide, dollar, datter
# ...

# %%
uforest = gnl.forest(uclique[2])

# %%
from pylab import rcParams
rcParams['figure.figsize'] = [18,18]

# %%
def draw_tree(G, node_size=1, node_color='slategrey', n=2, m = 1, h=10, v=10):
    #plt.subplot()
    draw_graph(G, h = h, v = v, layout= lambda g: gnl.tree_positions(g, n, increment=m), node_color=node_color, node_size=node_size, fontsize=18,arrows=False)
    fmin, fmax = plt.xlim()
    plt.xlim(fmin-10,fmax+10)
    #ax.set_xticks([])
    #ax.set_yticks([])
    #plt.savefig('krig.svg')

def draw_forest(F, spacing, h=15, v=10, save_name=False):
    import matplotlib.pyplot as plt
    
    #rows = len(F)
    #row = 1
    #plt.figsize=(15,10)
    for tree in F:
        #print(tree.nodes())
        #plt.subplot(rows,row,1)
        #plt.figure(row)
        #row += 1
        draw_tree(tree, node_size=0.5, h=h, v=v)
        if save_name:
            plt.savefig('{name}-{row}.png'.format(name=save_name, row=row, dpi=300))

# %%
gnl??

# %%
gnl.draw_forest(uforest,2, h=20, v=15)

# %%
nb.central_characters(ugraph, n=50)
# Out:
# [('reise', 0.5964912280701754),
#  ('Gud', 0.5526315789473684),
#  ('Minnesota', 0.5263157894736842),
#  ('Reise', 0.5263157894736842),
#  ('arbeide', 0.5),
#  ('Wisconsin', 0.47368421052631576),
#  ('Kone', 0.42105263157894735),
#  ('Arbeide', 0.4122807017543859),
#  ('arbeidet', 0.39473684210526316),
#  ('kone', 0.39473684210526316),
#  ('dollar', 0.38596491228070173),
#  ('Reisen', 0.3771929824561403),
#  ('Dollar', 0.3684210526315789),
#  ('datter', 0.35964912280701755),
#  ('Bergen', 0.35964912280701755),
#  ('Søn', 0.35964912280701755),
#  ('Jorden', 0.32456140350877194),
#  ('far', 0.3157894736842105),
#  ('mor', 0.3157894736842105),
#  ('gud', 0.2982456140350877),
#  ('reisen', 0.2894736842105263),
#  ('Datter', 0.2894736842105263),
#  ('Jord', 0.24561403508771928),
#  ('Dakota', 0.24561403508771928),
#  ('hav', 0.24561403508771928),
#  ('Arbeidet', 0.23684210526315788),
#  ('Mor', 0.23684210526315788),
#  ('jord', 0.23684210526315788),
#  ('rige', 0.22807017543859648),
# ...

# %%
nb.get_urnkonk('Rige', {'urns':urns})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010051906100?searchText=Rige' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>over til Amerika ligesom den</td>
#                 <td>Rige</td>
#                 <td style='text-align:left'>Mand lenges efter at gaae</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010051906100?searchText=Rige' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>vores Aviser om den forundringsfulde</td>
#                 <td>Rige</td>
#                 <td style='text-align:left'>guldgrund i Callifornia ; saa</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
nb.get_urnkonk('reise', {'urns':[u], 'size':50})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013010308006?searchText=reise' target='_blank' style='text-decoration:none'>Amerikabrev, , 2000</a>
#                 </td>
#                 <td>de aldrig tænker paa at</td>
#                 <td>reise</td>
#                 <td style='text-align:left'>hertil . " Slike uttalelser</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013010308006?searchText=reise' target='_blank' style='text-decoration:none'>Amerikabrev, , 2000</a>
#                 </td>
#                 <td>vi jo komme til at</td>
#                 <td>reise</td>
#                 <td style='text-align:left'>Sammen enten du faar Billet</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
nb.get_urnkonk('Slaveri', {'urns':urns, 'size':50})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010051906100' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>var at samenligne med et</td>
#                 <td>Slaveri</td>
#                 <td style='text-align:left'>, deres bedragelige Karagteer var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007091801006' target='_blank' style='text-decoration:none'>Fra Amerika til Norge, , 1992</a>
#                 </td>
#                 <td>, dersom her ikke var</td>
#                 <td>Slaveri</td>
#                 <td style='text-align:left'>og jeg har en bestandig</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
G[u].nodes(data=True)
# Out:
# NodeDataView({'Arendal': {}, 'Hallingdal': {}, 'Bergen': {}, 'Lillehammer': {}, 'Minnesota': {}, 'Oslo': {}, 'Telemark': {}, 'Dakota': {}, 'Jord': {}, 'Valdres': {}, 'Wisconsin': {}, 'arbeidet': {}, 'far': {}, 'reise': {}, 'Gud': {}, 'Kone': {}, 'Sjøen': {}, 'arbeide': {}, 'gud': {}, 'jorden': {}, 'kone': {}, 'rige': {}, 'Minneapolis': {}, 'sønn': {}, 'Oppland': {}, 'Reise': {}, 'Reisen': {}, 'Rogaland': {}, 'jorda': {}, 'arbeid': {}, 'dollar': {}, 'mor': {}, 'havet': {}, 'reisen': {}})
